# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
from scipy.stats import skew

# %%
df = pd.read_csv("DATOS/df_pets.csv", index_col= "Unnamed: 0")

# %% [markdown]
# <p>1. Extraer los siguentes estadísiticos del conjunto de datos para varias de las varibles disponibles:</p>

# %% [markdown]
# - Tabla de contingencia

# %%
df.sample(2)
# Out:
#                 Location  Number of Households (in 1000)  \
# 21             Minnesota                            2.16
# 7   District of Columbia                          287.00
#
#     Percentage of households with pets  Number of Pet Households (in 1000)  \
# 21                                53.0                                1.15
# 7                                 21.9                               63.00
#
#     Percentage of Dog Owners  Dog Owning Households (1000s)  \
# 21                      31.9                          690.0
# 7                       13.1                           38.0
#
#     Mean Number of Dogs per household  Dog Population (in 1000)  \
# 21                                1.4                     934.0
# 7                                 1.1                      42.0
#
#     Percentage of Cat Owners  Cat Owning Households  Mean Number of Cats  \
# 21                      29.7                  643.0                  2.0
# ...

# %%
df_pets_contingencia = pd.crosstab(df["Location"], df["dog_owning_category"])
df_pets_contingencia
# Out:
# dog_owning_category   alta  baja  media
# Location
# Alabama                  1     0      0
# Arizona                  0     1      0
# Arkansas                 1     0      0
# California               0     1      0
# Colorado                 1     0      0
# Connecticut              0     0      1
# Delaware                 0     1      0
# District of Columbia     0     1      0
# Florida                  0     1      0
# Georgia                  0     1      0
# Idaho                    0     1      0
# Illinois                 0     1      0
# Indiana                  1     0      0
# Iowa                     0     0      1
# Kansas                   0     0      1
# Kentucky                 1     0      0
# Louisiana                1     0      0
# Maine                    0     1      0
# Maryland                 1     0      0
# Massachusetts            1     0      0
# Michigan                 0     1      0
# Minnesota                1     0      0
# ...

# %% [markdown]
# - Coeficiente de correlación de las variables numéricas del dataset.

# %%
matriz_correlacion = df.corr()
matriz_correlacion
# Out:
#                                     Number of Households (in 1000)  \
# Number of Households (in 1000)                            1.000000
# Percentage of households with pets                        0.095171
# Number of Pet Households (in 1000)                        0.383689
# Percentage of Dog Owners                                  0.161893
# Dog Owning Households (1000s)                            -0.028676
# Mean Number of Dogs per household                         0.136737
# Dog Population (in 1000)                                  0.259266
# Percentage of Cat Owners                                  0.060711
# Cat Owning Households                                    -0.222808
# Mean Number of Cats                                       0.084337
# Cat Population                                            0.515656
#
#                                     Percentage of households with pets  \
# Number of Households (in 1000)                                0.095171
# ...

# %%
import matplotlib.pyplot as plt

# establecemos el tamaño de la gráfica
plt.figure(figsize = (10,10))

# creamos la gráfica
sns.heatmap(df.corr(), # lo que queremos visualizar
            cmap = "mako", # color del gráfico
            annot = True, # para que nos aparezcan los valores de la correlacion
            vmin = -1, # establecemos el valor mínimo de la escala de color
            vmax = 1 # establecemos el valor máximo de la escala de color
);

# %% [markdown]
# - Sesgos de alguna de las variables numéricas del dataset.

# %%
sns.displot(df["Cat Population"],
            color = "green",
            kde = True);

# %%
skewness = skew(df['Cat Population'])
print(f"El valor del sesgo para la variable Cat Population es: {skewness}")
# Out:
# El valor del sesgo para la variable Cat Population es: 1.1775294300512407

# %% [markdown]
# - Intervalo de confianza de algunas de las variables numéricas del dataset

# %%
import scipy.stats as st

datos = df['Cat Owning Households']


print(st.t.interval(alpha=0.95, df=len(datos)-1, loc=np.mean(datos), scale=st.sem(datos)))


print(np.mean(datos))
# Out:
# (246.55944097965255, 415.7454569795311)
# 331.15244897959184

# %% [markdown]
# - Interpretación de los resultados.

# %% [markdown]
# <p>La población de gatos está sesgada a la izquierda, y la media de hogares con gatos por estado es de 331</p>

# %% [markdown]
# <p>2. Ahora interpreta los resultados obtenidos de los diferentes estadísticos estudiados haciendo hincapié en aspectos interesantes de tus datos y explica lo mejor posible la naturaleza de los mismos.</p>

# %% [markdown]
# <p> Hemos encontrado que existe un alto porcentaje de hogares con mascota, pero con respecto a la población de gatos y perros hemos encontrado datos dispares. Mientras que la población de perros está vinculada a gente con perros como mascota, la población de gatos no lo está. Eso significa que hay un amplio porcentaje de la población de gatos que vive en colonias.</p>
